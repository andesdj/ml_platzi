# %%
import pandas as pd
pd.options.display.max_rows=20
clean_u=pd.read_csv('datasets/clean_eluniversal.csv')
clean_p=pd.read_csv('datasets/clean_elpais.csv')

clean_p.head()
# Out:
#    Unnamed: 0                                               body  \
# 0           0  Mi hermana está enferma y yo tengo la culpa, l...
# 1           1  Los aeropuertos de la red de Aena han cerrado ...
# 2           2  Los ministros de Finanzas de la UE demostraron...
# 3           3  The Spanish government is considering creating...
# 4           4  Logo de Zoom, una de las aplicaciones más popu...
#
#                                                title  \
# 0       todo el mundo en wuhan padece un trauma.html
# 1  solo un 3 de los vuelos habituales aterrizan a...
# 2  la ue acuerda desbloquear las ayudas de medio ...
# 3  coronavirus measures in spain a horizon of nor...
# 4  crece el numero de empresas que prohiben a sus...
#
#                                                  url newspaper_uid  \
# 0  https://www.elpais.com/sociedad/2020-04-10/tod...    elpais.csv
# 1  https://www.elpais.com/economia/2020-04-09/sol...    elpais.csv
# ...

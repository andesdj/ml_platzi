# %%
import pandas as pd
pd.options.display.max_rows=20
cleanU=pd.read_csv('datasets/clean_eluniversal.csv')
cleanP=pd.read_csv('datasets/clean_elpais.csv')
cleanU.head()
# Out:
#    Unnamed: 0                                               body  \
# 0           0  No sabía si iba a sobrevivir, dijo la cantante...
# 1           1  El presidente Andrés Manuel López Obrador info...
# 2           2  La Secretaría de Salud confirmó tres nuevos fa...
# 3           3  Como había anunciado ayer, Andrés Manuel López...
# 4           4  Ana Claudia Talancón anda activa promoviendo a...
#
#                                                title  \
# 0  pink revela sus momentos mas dificiles al cont...
# 1  México acuerda con OPEP reducir en 100 mil bar...
# 2  Fallecen tres personas más por coronavirus en ...
# 3  AMLO dice que envió listado al CCE de los 15 g...
# 4  Ana Claudia Talancón promueve el sazón de su p...
#
#                                                  url    newspaper_uid  \
# 0  https://www.viveusa.mx/showbiz/pink-revela-sus...  eluniversal.csv
# 1  https://www.eluniversal.com.mx/nacion/amlo-mex...  eluniversal.csv
# ...

# %%
# %matplotlib inline
cleanP['n_tokens_title'].plot(style='k.')
cleanU['n_tokens_title'].plot(style='r.')

# %%
# %matplotlib inline
(cleanP['n_tokens_body']/2).plot(style='k.')
(cleanU['n_tokens_body']/2).plot(style='r.')

# %%
todos=pd.concat([cleanU, cleanP])
grouped= todos.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# elpais.csv         [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# eluniversal.csv    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean' , 'max'])
# Out:
#                  min        mean   max
# newspaper_uid
# elpais.csv        22  660.854167  5544
# eluniversal.csv    9  264.717391  1034

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais.csv         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal.csv    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
